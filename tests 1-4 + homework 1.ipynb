# %%
name = input("Введите ваше имя")
print("Привет" + name)
# Out:
# Введите ваше имя nastya
# Привет nastya

# %%
number = int(input("Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4, "))
print(f"{number}*2 = {number*2} +8 = {number*2+8} //2 = {(number*2+8)//2} -{number} = {((number*2+8)//2) - number}")
print (number)
# Out:
# Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4, 6
# 6*2 = 12 +8 = 20 //2 = 10 -6 = 4
# 6

# %%
number = int(input("Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4, "))
b = number*2
print(f"{number} умножить на 2 равно и получим {number*2}")
b = number+8
print(f"{number} прибавить 8 и получим {number*2}")
b = number//2
print(f"{number} разделить на 2 и получим {number*2}")
b = number-b
print(f"{number} отнять {number} и получим {number*2}")
# Out:
# Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4, 2
# 2 умножить на 2 равно и получим 4
# 2 прибавить 8 и получим 4
# 2 разделить на 2 и получим 4
# 2 отнять 2 и получим 4

# %%
number = int(input("Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4,"))
number1 = number*2
print(f"{number}*2 = {number1}")
number2 = number1+8
print(f"{number1}+8 = {number2}")
number3 = number2//2
print(f"{number2}//2 = {number3}")
number4 = number3-number
print(f"{number3} - {number} = 4")
# Out:
# Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4,6
# 6*2 = 12
# 12+8 = 20
# 20//2 = 10
# 10 - 6 = 4

# %%
name = input ("Как вас зовут?")
print("В вашем имени", len(name), "букв(ы)")
# Out:
# Как вас зовут?настя
# В вашем имени 5 букв(ы)

# %%
name1 = input("Какой президент правил в год вашего рождения?")
name2 = input("Какой президент правит сейчас?")
print(name1==name2)
# Out:
# Какой президент правил в год вашего рождения?Путин В.В.
# Какой президент правит сейчас?Путин В.В.
# True

# %%
number = int(input("Введите целое число"))
previous_number= number-1
next_number=number+1
print(f"предыдущее = {previous_number}, само число = {number}, следующее число ={next_number}")
# Out:
# Введите целое число9
# предыдущее = 8, само число = 9, следующее число =10

# %%
number = int(input("Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4,"))
number1 = number*2
print(f"{number}*2 = {number1}")
number2 = number1+8
print(f"{number1}+8 = {number2}")
number3 = number2//2
print(f"{number2}//2 = {number3}")
number4 = number3-number
print(f"{number3} - {number} = 4")
# Out:
# Введите число.Какое бы число вы не ввели, после математических операций вы получите число 4,6
# 6*2 = 12
# 12+8 = 20
# 20//2 = 10
# 10 - 6 = 4

# %%
name=int(input())
print(name*2)
# Out:
# 2
# 4

# %%
a = input()
b = input()
if a==b :
 print(f"{a} равно {b}")
else :
 print(f"{a} не равно {b}")
# Out:
# 5
# 6
# 5 не равно 6

# %%
a = input()
b = input()
if a==b:
  print(a + "равно" + b)
else:
  print(a + "не равно" + b)
# Out:
# 4
# 5
# 4не равно5

# %%
a =int(input())
b =int(input())
if a==b :
  print(a , "равно" , b)
else:
  print(a , "не равно" , b)
# Out:
# 5
# 6
# 5 не равно 6
